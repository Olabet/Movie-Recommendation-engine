# %%
# import the libaries 
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# Load the data
links=pd.read_csv('Datasets/links.csv')
movies=pd.read_csv('Datasets/movies.csv')
ratings=pd.read_csv('Datasets/ratings.csv')
tags=pd.read_csv('Datasets/tags.csv')

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
ratings['rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# merge movie and rating
ratings_movie=pd.merge( movies,ratings, how = 'left', on = 'movieId')
ratings_movie
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings_movie.shape
# Out:
# (100854, 6)

# %%
ratings_movie.groupby('title')['rating'].mean().head()
# Out:
# title
# '71 (2014)                                 4.0
# 'Hellboy': The Seeds of Creation (2004)    4.0
# 'Round Midnight (1986)                     3.5
# 'Salem's Lot (2004)                        5.0
# 'Til There Was You (1997)                  4.0
# Name: rating, dtype: float64

# %%
ratings_movie.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Gena the Crocodile (1969)              5.0
# True Stories (1986)                    5.0
# Cosmic Scrat-tastrophe (2015)          5.0
# Love and Pigeons (1985)                5.0
# Red Sorghum (Hong gao liang) (1987)    5.0
# Name: rating, dtype: float64

# %%
ratings_mean_count=pd.DataFrame(ratings_movie.groupby('title')['rating'].mean())
ratings_mean_count
# Out:
#                                              rating
# title
# '71 (2014)                                 4.000000
# 'Hellboy': The Seeds of Creation (2004)    4.000000
# 'Round Midnight (1986)                     3.500000
# 'Salem's Lot (2004)                        5.000000
# 'Til There Was You (1997)                  4.000000
# ...                                             ...
# eXistenZ (1999)                            3.863636
# xXx (2002)                                 2.770833
# xXx: State of the Union (2005)             2.000000
# ¡Three Amigos! (1986)                      3.134615
# À nous la liberté (Freedom for Us) (1931)  1.000000
#
# [9737 rows x 1 columns]

# %%
ratings_mean_count['rating_counts']=pd.DataFrame(ratings_movie.groupby('title')['rating'].count())

# %%
ratings_mean_count
# Out:
#                                              rating  rating_counts
# title
# '71 (2014)                                 4.000000              1
# 'Hellboy': The Seeds of Creation (2004)    4.000000              1
# 'Round Midnight (1986)                     3.500000              2
# 'Salem's Lot (2004)                        5.000000              1
# 'Til There Was You (1997)                  4.000000              2
# ...                                             ...            ...
# eXistenZ (1999)                            3.863636             22
# xXx (2002)                                 2.770833             24
# xXx: State of the Union (2005)             2.000000              5
# ¡Three Amigos! (1986)                      3.134615             26
# À nous la liberté (Freedom for Us) (1931)  1.000000              1
#
# [9737 rows x 2 columns]

# %%
# merge rating_movie and tags
ratings_movie=pd.merge(ratings_movie, tags, how = 'left', on = 'movieId')
ratings_movie
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 285778   193581  Black Butler: Book of the Atlantic (2017)
# 285779   193583               No Game No Life: Zero (2017)
# 285780   193585                               Flint (2017)
# 285781   193587        Bungo Stray Dogs: Dead Apple (2018)
# 285782   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       1.0     4.0
# ...
